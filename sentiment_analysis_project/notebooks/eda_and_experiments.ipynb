# %% [markdown]
# # Sentiment Analysis - EDA and Experiments
#
# This notebook contains exploratory data analysis and model experimentation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import sys

# Add project root to path
project_root = Path().resolve().parent.parent
sys.path.insert(0, str(project_root))

from src.data_processing.preprocess import TextPreprocessor, load_and_prepare_data
from src.models.lstm_model import build_bidirectional_lstm_model

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
